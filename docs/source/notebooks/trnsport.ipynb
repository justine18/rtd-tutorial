# %% [markdown]
# ## Trnsport

# %%
x = 'Hello World'
x
# Out:
# 'Hello World'

# %%
from gamspy import Set, Parameter, Variable, Equation, Model, Container
from gamspy import Sum, Sense
import sys

# %%
def main():
    m = Container()

    # Prepare data
    distances = [
        ["seattle", "new-york", 2.5],
        ["seattle", "chicago", 1.7],
        ["seattle", "topeka", 1.8],
        ["san-diego", "new-york", 2.5],
        ["san-diego", "chicago", 1.8],
        ["san-diego", "topeka", 1.4],
    ]

    capacities = [["seattle", 350], ["san-diego", 600]]
    demands = [["new-york", 325], ["chicago", 300], ["topeka", 275]]

    # Set
    i = Set(m, name="i", records=["seattle", "san-diego"])
    j = Set(m, name="j", records=["new-york", "chicago", "topeka"])

    # Data
    a = Parameter(m, name="a", domain=[i], records=capacities)
    b = Parameter(m, name="b", domain=[j], records=demands)
    d = Parameter(m, name="d", domain=[i, j], records=distances)
    c = Parameter(m, name="c", domain=[i, j])
    c[i, j] = 90 * d[i, j] / 1000

    # Variable
    x = Variable(m, name="x", domain=[i, j], type="Positive")

    # Equation
    supply = Equation(m, name="supply", domain=[i])
    demand = Equation(m, name="demand", domain=[j])

    supply[i] = Sum(j, x[i, j]) <= a[i]
    demand[j] = Sum(i, x[i, j]) >= b[j]

    transport = Model(
        m,
        name="transport",
        equations=m.getEquations(),
        problem="LP",
        sense=Sense.MIN,
        objective=Sum((i, j), c[i, j] * x[i, j]),
    )
    transport.solve(output=sys.stdout)

    print(x.records)
    print(transport.objective_value)
    print(transport.status)

# %%
if __name__ == "__main__":
    main()
# Out:
# --- Job _gams_py_gjo0.gms Start 09/25/23 10:22:05 45.0.0 a37313c4 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\Users\jbroi\anaconda3\envs\test\Lib\site-packages\gamspy\minigams\windows\gmsprmNT.txt
#     C:\Users\jbroi\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     LP HIGHS
#     MIP HIGHS
#     RMIP HIGHS
#     NLP CONOPT
#     MCP PATH
#     MPEC NLPEC
#     RMPEC CONVERT
#     CNS CONOPT
#     DNLP CONOPT
#     RMINLP CONOPT
#     MINLP SBB
#     QCP CONOPT
#     MIQCP SBB
#     RMIQCP CONOPT
#     EMP CONVERT
#     Input C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\_gams_py_gjo0.gms
#     Output C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\_gams_py_gjo0.lst
#     Save C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default_save.g00
#     ScrDir C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\225a\
#     SysDir C:\Users\jbroi\anaconda3\envs\test\Lib\site-packages\gamspy\minigams\windows\
#     CurDir C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\
#     LogOption 3
#     LogFile C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\_gams_py_gjo0.log
#     GDX C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# *** ************* ALPHA release
# *** GAMS Base Module 45.0.0 a37313c4 Sep 14, 2023  (ALPHA) WEI x86 64bit/MS Window
# *** ************* ALPHA release
# Licensee: GAMS Working License                           S230720|0002CO-GEN
#           GAMS Software GmbH, Braunschweig Office                   DCE2920
#           C:\Users\jbroi\Documents\GAMS\gamslice.txt
#           License Admin: Justine Broihan, jbroihan@gams.com
#           Evaluation license: Not for commercial or production use
#           The evaluation period of the license will expire on Jan 16, 2024
# Processor information: 1 socket(s), 12 core(s), and 16 thread(s) available
# GAMS 45.0.0   Copyright (C) 1987-2023 GAMS Development. All rights reserved
# --- Starting compilation
# --- _gams_py_gjo0.gms(2) 2 Mb
# --- GDXin=C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- GDX File ($gdxLoad) C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- _gams_py_gjo0.gms(5) 3 Mb
# --- GDXin=C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- GDX File ($gdxLoad) C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- _gams_py_gjo0.gms(8) 3 Mb
# --- GDXin=C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- GDX File ($gdxLoad) C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- _gams_py_gjo0.gms(11) 3 Mb
# --- GDXin=C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- GDX File ($gdxLoad) C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- _gams_py_gjo0.gms(14) 3 Mb
# --- GDXin=C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- GDX File ($gdxLoad) C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- _gams_py_gjo0.gms(17) 3 Mb
# --- GDXin=C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- GDX File ($gdxLoad) C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- _gams_py_gjo0.gms(22) 3 Mb
# --- GDXin=C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- GDX File ($gdxLoad) C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- _gams_py_gjo0.gms(25) 3 Mb
# --- GDXin=C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- GDX File ($gdxLoad) C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- _gams_py_gjo0.gms(28) 3 Mb
# --- GDXin=C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- GDX File ($gdxLoad) C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- _gams_py_gjo0.gms(35) 3 Mb
# --- GDXin=C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- GDX File ($gdxLoad) C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- _gams_py_gjo0.gms(38) 3 Mb
# --- GDXin=C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- GDX File ($gdxLoad) C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# --- _gams_py_gjo0.gms(93) 3 Mb
# --- Starting execution: elapsed 0:00:00.108
# --- _gams_py_gjo0.gms(19) 4 Mb
# --- Generating LP model transport
# --- _gams_py_gjo0.gms(68) 4 Mb
# ---   6 rows  7 columns  19 non-zeroes
# --- Range statistics (absolute non-zero finite values)
# --- RHS       [min, max] : [ 2.750E+02, 6.000E+02] - Zero values observed as well
# --- Bound     [min, max] : [        NA,        NA] - Zero values observed as well
# --- Matrix    [min, max] : [ 1.260E-01, 1.000E+00]
# --- Executing HIGHS (Solvelink=2): elapsed 0:00:00.162
#
# HIGHS            45.0.0 a37313c4 Sep 14, 2023  (ALPHA) WEI x86 64bit/MS Window
#
# Running HiGHS 1.5.4 [git hash: 977756503]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Options set:
#   time_limit           = 1e+10
#   threads              = 1
#   mip_abs_gap          = 0
#
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0     0.0000000000e+00 Pr: 3(900) 0s
#           3     1.5367500000e+02 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 3
# Objective value     :  1.5367500000e+02
# HiGHS run time      :          0.00
# --- Reading solution for model transport
# --- Executing after solve: elapsed 0:00:00.709
# --- _gams_py_gjo0.gms(93) 4 Mb
# --- GDX File C:\Users\jbroi\AppData\Local\Temp\tmplbhbmwxs\default.gdx
# *** Status: Normal completion
# --- Job _gams_py_gjo0.gms Stop 09/25/23 10:22:06 elapsed 0:00:00.711
#            i         j  level  marginal  lower  upper  scale
# 0    seattle  new-york    0.0    -0.000    0.0    inf    1.0
# 1    seattle   chicago  300.0     0.000    0.0    inf    1.0
# 2    seattle    topeka    0.0     0.036    0.0    inf    1.0
# 3  san-diego  new-york  325.0     0.000    0.0    inf    1.0
# 4  san-diego   chicago    0.0     0.009    0.0    inf    1.0
# 5  san-diego    topeka  275.0     0.000    0.0    inf    1.0
# 153.675
# ModelStatus.OptimalGlobal
